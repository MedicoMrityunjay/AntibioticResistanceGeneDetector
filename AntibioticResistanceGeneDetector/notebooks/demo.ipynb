# %%
from src.gene_detector import detect_genes
from src.interpret_results import interpret_hits, write_report

input_fasta = 'input/example.fasta'
db_fasta = 'data/resistance_genes.fasta'
map_path = 'data/gene_class_map.csv'

hits = detect_genes(input_fasta, db_fasta)
results = interpret_hits(hits, map_path)
write_report(results, 'output/results.csv')
results

# %% [markdown]
# ## Output Table
# The detected resistance genes and their antibiotic classes are shown below.

# %%
import pandas as pd
pd.read_csv('output/results.csv')
